# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
# data = {'YearsExp':[1,2,3,4,5], 'salary' : [35000, 40000, 50000, 60000, 75000]}
# df = pd.DataFrame(data)

# %%
# x = pd.DataFrame(data)
# y= pd.DataFrame(data)
# model = LinearRegression()
# model.fit(x,y)

# %%
# print("Predict salary for a person with 7 years of expe", model.predict([[7]]))

# %%
# data =  {'Rooms':[1,2,3,4,5], 'Area': [300, 700,1000, 1200, 1700], 'Price' =[3,5,8,10,13]}
# df = pd.DataFrame(data)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


data1 = {
    'Room' : [1,2,3,4,5,6],
    'Price' : [10,20,35,40,47,58]
}

df = pd.DataFrame(data1)
x = df[['Room']]
y = df[['Price']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred= model.predict(x_test)

plt.scatter(x_test, y_test, color='blue',label="Actual")
plt.plot(x_test, y_pred, color="red", linewidth=2, label='Predicted')
plt.xlabel("Number of rooms")
plt.ylabel("House price")
plt.legend()
plt.grid(True)
plt.show()

# %%
mae= mean_absolute_error(y_test, y_pred)
mse= mean_squared_error(y_test, y_pred)
rmse= np.sqrt(mse)
r2= r2_score(y_test, y_pred)
print("Evluation:")
print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}") #linear rigression model
# Out:
# Evluation:
# MAE: 3.15
# MSE: 16.68
# RMSE: 4.08
# R2: 0.87
